# %%
def gcd_extended(a, b):
    if a == 0:
        return b, 0, 1
    else:
        gcd, x1, y1 = gcd_extended(b % a, a)
        x = y1 - (b // a) * x1
        y = x1
        return gcd, x, y

def modular_inverse(a, n):
    gcd, x, y = gcd_extended(a, n)
    if gcd != 1:
        raise ValueError(f"{a} has no modular inverse modulo {n}")
    else:
        return x % n

def pollards_rho(alpha, beta, n):
    x0, a0, b0 = 1, 0, 0
    x, a, b = x0, a0, b0
    x2, a2, b2 = x0, a0, b0

    while True:
        x = (x * alpha) % n
        a = (a + 1) % n
        b = (b + x) % n

        x2 = (x2 * alpha) % n
        a2 = (a2 + 1) % n
        b2 = (b2 + x2) % n
        x2 = (x2 * alpha) % n
        a2 = (a2 + 1) % n
        b2 = (b2 + x2) % n

        if x == x2:
            r = (b - b2) % n
            if r == 0:
                return None
            else:
                try:
                    x_inv = modular_inverse(r, n)
                    result = (x_inv * (a2 - a)) % n
                    return result
                except ValueError:
                    continue

# Testing
import random

for _ in range(100):
    alpha = random.randint(2, 100)
    beta = random.randint(2, 100)
    n = random.randint(101, 99999)
    
    result = pollards_rho(alpha, beta, n)
    print(f"Test {_ + 1}: alpha={alpha}, beta={beta}, n={n}, result={result}")
# Out:
# Test 1: alpha=61, beta=18, n=74334, result=None
# Test 2: alpha=27, beta=29, n=30884, result=None
# Test 3: alpha=54, beta=52, n=14492, result=None
# Test 4: alpha=63, beta=4, n=60737, result=None
# Test 5: alpha=73, beta=44, n=37134, result=None
# Test 6: alpha=92, beta=4, n=58347, result=None
# Test 7: alpha=99, beta=6, n=69548, result=None
# Test 8: alpha=43, beta=63, n=17891, result=None
# Test 9: alpha=41, beta=23, n=93485, result=None
# Test 10: alpha=87, beta=43, n=11269, result=None
# Test 11: alpha=39, beta=76, n=79188, result=None
# Test 12: alpha=13, beta=55, n=68707, result=None
# Test 13: alpha=60, beta=58, n=97545, result=None
# Test 14: alpha=3, beta=75, n=32131, result=None
# Test 15: alpha=15, beta=8, n=38957, result=None
# Test 16: alpha=63, beta=54, n=76269, result=None
# Test 17: alpha=10, beta=20, n=14576, result=None
# Test 18: alpha=43, beta=65, n=88842, result=None
# Test 19: alpha=50, beta=7, n=89878, result=None
# Test 20: alpha=85, beta=73, n=11008, result=None
# Test 21: alpha=22, beta=46, n=47847, result=None
# Test 22: alpha=83, beta=68, n=50007, result=None
# Test 23: alpha=82, beta=51, n=91014, result=None
# Test 24: alpha=17, beta=75, n=59141, result=None
# Test 25: alpha=66, beta=50, n=78608, result=None
# Test 26: alpha=88, beta=12, n=22964, result=None
# Test 27: alpha=92, beta=19, n=85773, result=None
# Test 28: alpha=79, beta=76, n=16104, result=None
# Test 29: alpha=34, beta=81, n=26298, result=None
# Test 30: alpha=41, beta=22, n=92261, result=None
# Test 31: alpha=86, beta=52, n=31823, result=None
# Test 32: alpha=48, beta=50, n=54030, result=None
# Test 33: alpha=60, beta=11, n=63949, result=None
# Test 34: alpha=20, beta=68, n=18689, result=None
# Test 35: alpha=83, beta=34, n=60312, result=None
# Test 36: alpha=47, beta=79, n=61012, result=None
# Test 37: alpha=38, beta=64, n=54192, result=None
# Test 38: alpha=92, beta=57, n=5926, result=None
# Test 39: alpha=8, beta=70, n=12329, result=None
# Test 40: alpha=69, beta=38, n=70242, result=None
# Test 41: alpha=20, beta=34, n=96863, result=None
# Test 42: alpha=72, beta=67, n=89992, result=None
# Test 43: alpha=25, beta=9, n=67463, result=None
# Test 44: alpha=3, beta=7, n=11281, result=None
# Test 45: alpha=41, beta=16, n=14193, result=None
# Test 46: alpha=76, beta=57, n=19944, result=None
# Test 47: alpha=23, beta=65, n=46201, result=None
# Test 48: alpha=20, beta=33, n=39080, result=None
# Test 49: alpha=46, beta=31, n=86955, result=None
# Test 50: alpha=55, beta=19, n=97431, result=None
# Test 51: alpha=65, beta=19, n=83457, result=None
# Test 52: alpha=99, beta=91, n=86277, result=None
# Test 53: alpha=100, beta=23, n=97281, result=None
# Test 54: alpha=36, beta=51, n=49809, result=None
# Test 55: alpha=65, beta=60, n=75605, result=None
# Test 56: alpha=20, beta=66, n=54977, result=None
# Test 57: alpha=44, beta=25, n=62652, result=None
# Test 58: alpha=56, beta=40, n=46460, result=None
# Test 59: alpha=21, beta=93, n=8187, result=None
# Test 60: alpha=79, beta=6, n=68730, result=None
# Test 61: alpha=7, beta=2, n=34337, result=None
# Test 62: alpha=99, beta=17, n=98096, result=None
# Test 63: alpha=34, beta=38, n=43980, result=None
# Test 64: alpha=48, beta=4, n=72826, result=None
# Test 65: alpha=46, beta=93, n=32375, result=None
# Test 66: alpha=96, beta=92, n=71866, result=None
# Test 67: alpha=54, beta=87, n=47992, result=None
# Test 68: alpha=6, beta=44, n=14924, result=None
# Test 69: alpha=31, beta=72, n=315, result=None
# Test 70: alpha=53, beta=65, n=56962, result=None
# Test 71: alpha=36, beta=14, n=89247, result=None
# Test 72: alpha=91, beta=41, n=18961, result=None
# Test 73: alpha=71, beta=37, n=28330, result=None
# Test 74: alpha=87, beta=15, n=88455, result=None
# Test 75: alpha=13, beta=47, n=47555, result=None
# Test 76: alpha=74, beta=70, n=93162, result=None
# Test 77: alpha=39, beta=6, n=29797, result=None
# Test 78: alpha=38, beta=15, n=50509, result=None
# Test 79: alpha=48, beta=16, n=62330, result=None
# Test 80: alpha=90, beta=6, n=56007, result=None
# Test 81: alpha=29, beta=32, n=64221, result=None
# Test 82: alpha=14, beta=72, n=32594, result=None
# Test 83: alpha=62, beta=44, n=51712, result=None
# Test 84: alpha=84, beta=66, n=93905, result=None
# Test 85: alpha=21, beta=66, n=41701, result=None
# Test 86: alpha=61, beta=69, n=64384, result=None
# Test 87: alpha=86, beta=71, n=32942, result=None
# Test 88: alpha=96, beta=81, n=34682, result=None
# Test 89: alpha=33, beta=87, n=46139, result=None
# Test 90: alpha=87, beta=19, n=89205, result=None
# Test 91: alpha=27, beta=34, n=34401, result=None
# Test 92: alpha=75, beta=97, n=92449, result=None
# Test 93: alpha=48, beta=60, n=94307, result=None
# Test 94: alpha=7, beta=71, n=26354, result=None
# Test 95: alpha=68, beta=62, n=31533, result=None
# Test 96: alpha=45, beta=47, n=3390, result=None
# Test 97: alpha=62, beta=32, n=2471, result=None
# Test 98: alpha=75, beta=56, n=88183, result=None
# Test 99: alpha=90, beta=44, n=36711, result=None
# Test 100: alpha=4, beta=64, n=20963, result=None
